# %% [markdown]
# # Task4 : Exploratory Data Analysis on Dataset - Terrorism

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('globalterrorism.csv', encoding='latin1')

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  1.970000e+11   1970       7     2        NaN         0        NaN       58
# 1  1.970000e+11   1970       0     0        NaN         0        NaN      130
# 2  1.970010e+11   1970       1     0        NaN         0        NaN      160
# 3  1.970010e+11   1970       1     0        NaN         0        NaN       78
# 4  1.970010e+11   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
df.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
df.columns.values
# Out:
# array(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region', 'region_txt',
#        'provstate', 'city', 'latitude', 'longitude', 'specificity',
#        'vicinity', 'location', 'summary', 'crit1', 'crit2', 'crit3',
#        'doubtterr', 'alternative', 'alternative_txt', 'multiple',
#        'success', 'suicide', 'attacktype1', 'attacktype1_txt',
#        'attacktype2', 'attacktype2_txt', 'attacktype3', 'attacktype3_txt',
#        'targtype1', 'targtype1_txt', 'targsubtype1', 'targsubtype1_txt',
#        'corp1', 'target1', 'natlty1', 'natlty1_txt', 'targtype2',
#        'targtype2_txt', 'targsubtype2', 'targsubtype2_txt', 'corp2',
#        'target2', 'natlty2', 'natlty2_txt', 'targtype3', 'targtype3_txt',
#        'targsubtype3', 'targsubtype3_txt', 'corp3', 'target3', 'natlty3',
#        'natlty3_txt', 'gname', 'gsubname', 'gname2', 'gsubname2',
# ...

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'day','gname':'Group','country_txt':'Country','provstate':'State','city':'city','longitude':'longitude'
                   ,'latitude':'Latitude','weaptype1_txt':'Weapon','nkill':'kill','nwound':'wound','summary':'summary','attacktype1_txt':'Attacktype','targetype1_txt':'Targettype','nwound':'Wound'})
# Out:
#              eventid  Year  Month  day approxdate  extended resolution  \
# 0       1.970000e+11  1970      7    2        NaN         0        NaN
# 1       1.970000e+11  1970      0    0        NaN         0        NaN
# 2       1.970010e+11  1970      1    0        NaN         0        NaN
# 3       1.970010e+11  1970      1    0        NaN         0        NaN
# 4       1.970010e+11  1970      1    0        NaN         0        NaN
# ...              ...   ...    ...  ...        ...       ...        ...
# 181686  2.017120e+11  2017     12   31        NaN         0        NaN
# 181687  2.017120e+11  2017     12   31        NaN         0        NaN
# 181688  2.017120e+11  2017     12   31        NaN         0        NaN
# 181689  2.017120e+11  2017     12   31        NaN         0        NaN
# 181690  2.017120e+11  2017     12   31        NaN         0        NaN
#
#         country             Country  region  ... addnotes  \
# ...

# %%
df.shape
# Out:
# (181691, 135)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(56), int64(21), object(58)
# memory usage: 187.1+ MB

# %%
df.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002704e+11    2002.638997       6.467277      15.505650
# std    1.325955e+09      13.259430       3.388303       8.814043
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991020e+11    1991.000000       4.000000       8.000000
# 50%    2.009020e+11    2009.000000       6.000000      15.000000
# 75%    2.014080e+11    2014.000000       9.000000      23.000000
# max    2.017120e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
df.corr()
# Out:
#             eventid     iyear    imonth      iday  extended   country  \
# eventid    1.000000  0.999996  0.002705  0.018268  0.091762 -0.135039
# iyear      0.999996  1.000000  0.000139  0.018253  0.091754 -0.135023
# imonth     0.002705  0.000139  1.000000  0.005496 -0.000468 -0.006305
# iday       0.018268  0.018253  0.005496  1.000000 -0.004700  0.003468
# extended   0.091762  0.091754 -0.000468 -0.004700  1.000000 -0.020466
# ...             ...       ...       ...       ...       ...       ...
# nreleased -0.181613 -0.181556 -0.011535  0.001765 -0.192155 -0.044331
# INT_LOG   -0.143600 -0.143601 -0.002302 -0.001540  0.071768  0.069904
# INT_IDEO  -0.133252 -0.133253 -0.002034 -0.001622  0.075147  0.067564
# INT_MISC  -0.077851 -0.077847 -0.002554 -0.002027  0.027335  0.207281
# INT_ANY   -0.175606 -0.175596 -0.006336 -0.001200  0.080767  0.153118
#
#              region  latitude  longitude  specificity  ...  ransomamt  \
# ...

# %%
df.value_counts
# Out:
# <bound method DataFrame.value_counts of              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 0       1.970000e+11   1970       7     2        NaN         0        NaN
# 1       1.970000e+11   1970       0     0        NaN         0        NaN
# 2       1.970010e+11   1970       1     0        NaN         0        NaN
# 3       1.970010e+11   1970       1     0        NaN         0        NaN
# 4       1.970010e+11   1970       1     0        NaN         0        NaN
# ...              ...    ...     ...   ...        ...       ...        ...
# 181686  2.017120e+11   2017      12    31        NaN         0        NaN
# 181687  2.017120e+11   2017      12    31        NaN         0        NaN
# 181688  2.017120e+11   2017      12    31        NaN         0        NaN
# 181689  2.017120e+11   2017      12    31        NaN         0        NaN
# 181690  2.017120e+11   2017      12    31        NaN         0        NaN
#
# ...

# %%
df.columns
# Out:
# Index(['eventid', 'iyear', 'imonth', 'iday', 'approxdate', 'extended',
#        'resolution', 'country', 'country_txt', 'region',
#        ...
#        'addnotes', 'scite1', 'scite2', 'scite3', 'dbsource', 'INT_LOG',
#        'INT_IDEO', 'INT_MISC', 'INT_ANY', 'related'],
#       dtype='object', length=135)

# %%
df.dtypes
# Out:
# eventid       float64
# iyear           int64
# imonth          int64
# iday            int64
# approxdate     object
#                ...
# INT_LOG         int64
# INT_IDEO        int64
# INT_MISC        int64
# INT_ANY         int64
# related        object
# Length: 135, dtype: object

# %%
df.nunique()
# Out:
# eventid         576
# iyear            47
# imonth           13
# iday             32
# approxdate     2244
#               ...
# INT_LOG           3
# INT_IDEO          3
# INT_MISC          3
# INT_ANY           3
# related       14306
# Length: 135, dtype: int64

# %%
df.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
df.rename(columns={'iyear':'Year','imonth':'Month','iday':'day','gname':'Group','country_txt':'Country','longitude':'longitude',
                   'summary':'summary','attacktype1_txt':'Attacktype','targtype1_txt':'Targettype','nwound':'Wound'},inplace= True)

# %%
data = df[['Year','Month','day','Country','latitude','longitude',"Attacktype",'Wound','target1',
           'summary','Group','Targettype','motive']]

# %%
data.head()
# Out:
#    Year  Month  day             Country   latitude   longitude  \
# 0  1970      7    2  Dominican Republic  18.456792  -69.951164
# 1  1970      0    0              Mexico  19.371887  -99.086624
# 2  1970      1    0         Philippines  15.478598  120.599741
# 3  1970      1    0              Greece  37.997490   23.762728
# 4  1970      1    0               Japan  33.580412  130.396361
#
#                        Attacktype  Wound                  target1 summary  \
# 0                   Assassination    0.0             Julio Guzman     NaN
# 1     Hostage Taking (Kidnapping)    0.0  Nadine Chaval, daughter     NaN
# 2                   Assassination    0.0                 Employee     NaN
# 3               Bombing/Explosion    NaN             U.S. Embassy     NaN
# 4  Facility/Infrastructure Attack    NaN           U.S. Consulate     NaN
#
#                                 Group                   Targettype motive
# ...

# %%
data['Wound']=data['Wound'].fillna(0)
data['target1']= data['target1'].fillna(0)

# %%
plt.figure(figsize=(10,20))
cor = df.corr()
plt.show()

# %%
year = data['Year'].unique()
years_count = data['Year'].value_counts(dropna = False).sort_index()
plt.figure(figsize = (16,11))
sns.barplot(x=year,
           y=years_count,
           palette = "RdBu")
plt.xticks(rotation = 50)
plt.xlabel('Attacking Year',fontsize= 20)
plt.ylabel('Number of Attacks Each Year',fontsize=20)
plt.title('Attacks In Years',fontsize=30)
plt.show()

# %%
plt.subplots(figsize=(20,10))
sns.barplot(df['country'].value_counts()[:20].index)
plt.title('Top 20 most affected countries', fontsize=25)
plt.ylabel('Number of Attacks',fontsize=20)
plt.xlabel('country',fontsize=20)
plt.show()

# %%
plt.figure(figsize=(43,10))
sns.countplot(df['country'],palette="magma")
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(40,10))
sns.countplot(df['Month'],palette='viridis')
plt.title('Number of Terrorist Attacks per Month',fontsize='20')
plt.ylabel("Number of attacks")
plt.xlabel("Month")
plt.xticks(rotation='40')
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.title('Top 10 Affected Regions',fontsize='30')
df['region'].value_counts().head(30).plot(kind='pie',autopct='%.02f%%')
# Out:
# <AxesSubplot:title={'center':'Top 10 Affected Regions'}, ylabel='region'>

# %%
plt.figure(figsize=(40,10))
sns.countplot(df['Year'],palette='viridis')
plt.title('Number of Terrorist Attacks per Year',fontsize='20')
plt.ylabel("Number of attacks")
plt.xlabel("year")
plt.xticks(rotation='40')
plt.show()

# %%
plt.figure(figsize=(10,20))
plt.title('Top 10 Affected Country',fontsize='30')
df['country'].value_counts().head(30).plot(kind='pie',autopct='%.02f%%')
# Out:
# <AxesSubplot:title={'center':'Top 10 Affected Country'}, ylabel='country'>

# %%
plt.figure(figsize=(43,10))
sns.countplot(df['Attacktype'],palette="magma")
plt.xticks(rotation=90)
plt.show()
